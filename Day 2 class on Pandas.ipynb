# %% [markdown]
# <div id="myCarousel" class="carousel slide text-center" data-ride="carousel">
#
#   <div class="carousel-inner" role="listbox">
#     <div class="item active">
#     <h3 style="color: blue;">DataFrame(Pandas)</h3>
#     </div>z
#   </div>

# %%
import pandas as pd

# %%
data = pd.read_csv('Height_Weight.csv')

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 495    Female
# 496    Female
# 497    Female
# 498      Male
# 499      Male
# Name: Gender, Length: 500, dtype: object

# %%
data['Gender'][0] = 'Female'
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12884/920126925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender'][0] = 'Female'

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0    Female     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
data[['Gender','Weight']][0:5]
# Out:
#    Gender  Weight
# 0  Female      96
# 1    Male      87
# 2  Female     110
# 3  Female     104
# 4    Male      61

# %% [markdown]
# # loc and Iloc

# %%
data.loc[:5 ,['Gender','Weight']]
# Out:
#    Gender  Weight
# 0  Female      96
# 1    Male      87
# 2  Female     110
# 3  Female     104
# 4    Male      61
# 5    Male     104

# %%
data.loc[0,'Gender'] = 'Male'

# %%
kk = data.head(5)
kk.index = [2,3,4,5,6]

# %%
kk.iloc[:2,:]
# Out:
#   Gender  Height  Weight  Index
# 2   Male     174      96      4
# 3   Male     189      87      2

# %%
# iloc

# %%
data.iloc[:5,3]
# Out:
# 0    4
# 1    2
# 2    4
# 3    3
# 4    3
# Name: Index, dtype: int64

# %%
data.iloc[4,2] = 100

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149     100      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %% [markdown]
# # Drop columns

# %%
data.drop('Index', axis = 'columns', inplace = True)

# %%
data
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149     100
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149     100      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
data
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149     100
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %%
data[data['Gender'] == 'Male']
# Out:
#     Gender  Height  Weight
# 0     Male     174      96
# 1     Male     189      87
# 4     Male     149     100
# 5     Male     189     104
# 6     Male     147      92
# ..     ...     ...     ...
# 487   Male     187      80
# 488   Male     198     136
# 494   Male     152      98
# 498   Male     150      95
# 499   Male     173     131
#
# [245 rows x 3 columns]

# %%
data['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498     True
# 499     True
# Name: Gender, Length: 500, dtype: bool

# %%
data[data['Height']>=149]
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149     100
# ..      ...     ...     ...
# 494    Male     152      98
# 495  Female     150     153
# 496  Female     184     121
# 498    Male     150      95
# 499    Male     173     131
#
# [437 rows x 3 columns]

# %%
data[(data['Height']>=149) | (data['Height']<=185)]
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149     100
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %%
data['Height'].mean()
# Out:
# 169.944

# %%
data['Height'].max()
# Out:
# 199

# %%
data1 = data[(data['Gender']=='Male') & (data['Height']>=data['Height'].mean())]

# %%
data1['Gender'].unique()
# Out:
# array(['Male'], dtype=object)

# %%
data1['Height'] = data1['Height'].astype('object')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12884/3742755147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Height'] = data1['Height'].astype('object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  128 non-null    object
#  1   Height  128 non-null    object
#  2   Weight  128 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 4.0+ KB

# %%
data1['Gender'].apply(lambda x:x[-2:] + ' Vikash')
# Out:
# 0      le Vikash
# 1      le Vikash
# 5      le Vikash
# 8      le Vikash
# 10     le Vikash
#          ...
# 475    le Vikash
# 485    le Vikash
# 487    le Vikash
# 488    le Vikash
# 499    le Vikash
# Name: Gender, Length: 128, dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  128 non-null    object
#  1   Height  128 non-null    object
#  2   Weight  128 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 4.0+ KB

# %%
k = lambda x : x[2:]
print(k('Male'))
# Out:
# le

# %%
x = 'Male'
print(x[-2:])
# Out:
# le
