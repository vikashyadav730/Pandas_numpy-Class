# %% [markdown]
# <h2><img src="https://www.pentagonspace.in/assets/images/logo/logo-dark.png" alt="pentagonspace.com/" align=left></h2>
# <div class="a" align=right>
#     <font style="border:white; border-width:10px; border-style:outset;"width="100" height="100" color="green" >
# Class Notes </font>
# </div >
#
# <div id="myCarousel" class="carousel slide text-center" data-ride="carousel">
#
#   <div class="carousel-inner" role="listbox">
#     <div class="item active">
#     <h3 style="color: blue;">DataFrame(Pandas)</h3>
#     </div>
#   </div>

# %% [markdown]
# # Missing Values

# %% [markdown]
# **1) A Simple Option: Drop Columns with Missing Values**
# <h2><img src="https://i.imgur.com/Sax80za.png" align=left></h2>

# %% [markdown]
# **2) A Better Option: Imputation**
# **Imputation** fills in the missing values with some number. For instance, we can fill in the mean value along each column
# <h2><img src="https://i.imgur.com/4BpnlPA.png" align=left></h2>

# %% [markdown]
# **3) An Extension To Imputation**
# Imputation is the standard approach, and it usually works well. However, imputed values may be systematically above or below their actual values (which weren't collected in the dataset). Or rows with missing values may be unique in some other way. In that case, your model would make better predictions by considering which values were originally missing
# <h2><img src="https://i.imgur.com/UWOyg4a.png" align=left></h2>

# %%
import pandas as pd
data = pd.read_csv('weather_data.csv')

# %%
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
data.isnull()
# Out:
#      day  temperature  windspeed  event
# 0  False        False      False  False
# 1  False         True      False  False
# 2  False        False       True  False
# 3  False         True      False   True
# 4  False        False       True  False
# 5  False        False      False  False
# 6  False        False      False   True

# %%
# k = data.isnull().sum().sum()
k = data.isnull().sum()
k2 = 0
for i in k:
    k2 = k2 + i
k2
# Out:
# 6

# %%
Tem_min = data['temperature'].mean()

# %%
data.fillna(data['temperature'].mean())
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         31.4        7.0  Sunny
# 2  1/3/2017         28.0       31.4   Snow
# 3  1/4/2017         31.4        7.0   31.4
# 4  1/5/2017         32.0       31.4   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0   31.4

# %%
data['temperature'] = data['temperature'].fillna(data['temperature'].mean())

# %%
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
data.fillna(method = 'ffill')
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0   Snow
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
data.fillna(method = 'bfill')
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0  Sunny
# 1  1/2/2017         28.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         32.0        7.0   Rain
# 4  1/5/2017         32.0        2.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
data.dropna(axis = 1)
# Out:
#         day
# 0  1/1/2017
# 1  1/2/2017
# 2  1/3/2017
# 3  1/4/2017
# 4  1/5/2017
# 5  1/6/2017
# 6  1/6/2017

# %%
data
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
data.dropna(subset = ['temperature','event'])
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017         28.0        NaN   Snow
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
