# %% [markdown]
# <div id="myCarousel" class="carousel slide text-center" data-ride="carousel">
#
#   <div class="carousel-inner" role="listbox">
#     <div class="item active">
#     <h3 style="color: blue;">DataFrame(Pandas)</h3>
#     </div>
#   </div>

# %% [markdown]
# # **`DataFrame`**
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %% [markdown]
# <h2><img src="https://www.tutorialspoint.com/python_pandas/images/structure_table.jpg" align=left></h2>

# %% [markdown]
# A pandas DataFrame can be created using the following constructor −
# >`pandas.DataFrame( data, index, columns, dtype)`

# %% [markdown]
# **Parameter & Description**
# 1.**data**
# >data takes various forms like ndarray, series, map, lists, dict, constants and also another DataFrame.
#
# 2.**index**
# >For the row labels, the Index to be used for the resulting frame is Optional Default np.arange(n) if no index is passed.
#
# 3.**columns**
# >For column labels, the optional default syntax is - np.arange(n). This is only true if no index is passed.
#
# 4.**dtype**
# >Data type of each column.

# %%
import pandas as pd

# %%
data = pd.DataFrame()

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
kk = [3,4,5,6,7,8,8]
dataset = pd.DataFrame(kk)

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
dd2 = {'AIRLINE_code': ['NS','UF','6W','AZ','HU','5W','UD','IB','N4','QBA','CY','7B','VRH','GE','QH','KLJ'],
       'AIRLINE_NAME':['Nesma Airlines','PETROLEUM AIR','FLYBOSNIA','Alitalia Societa Aerea','Hainan Airlines Holding','Wizz Air Abu Dhabi LLC dba','UR AIRLINES dba',
                       'Iberia','Nordwind Airlines','Queen Bilqis Airways','Charlie Airlines','Limited Liability Company Bees Airline'
                      ,'Varesh Air','Global Aviation Operations','Bamboo Airways','Verslo skrydziai JSC']}

# %%
dd2
# Out:
# {'AIRLINE_code': ['NS',
#   'UF',
#   '6W',
#   'AZ',
#   'HU',
#   '5W',
#   'UD',
#   'IB',
#   'N4',
#   'QBA',
#   'CY',
#   '7B',
#   'VRH',
#   'GE',
#   'QH',
#   'KLJ'],
#  'AIRLINE_NAME': ['Nesma Airlines',
#   'PETROLEUM AIR',
#   'FLYBOSNIA',
#   'Alitalia Societa Aerea',
#   'Hainan Airlines Holding',
#   'Wizz Air Abu Dhabi LLC dba',
#   'UR AIRLINES dba',
#   'Iberia',
#   'Nordwind Airlines',
#   'Queen Bilqis Airways',
#   'Charlie Airlines',
#   'Limited Liability Company Bees Airline',
#   'Varesh Air',
#   'Global Aviation Operations',
#   'Bamboo Airways',
#   'Verslo skrydziai JSC']}

# %%
import numpy as np
data = pd.DataFrame(dd2)

# %%
# data.columns = ['Airline_code','Airline_name']

# %%
data
# Out:
#    AIRLINE_code                            AIRLINE_NAME
# 0            NS                          Nesma Airlines
# 1            UF                           PETROLEUM AIR
# 2            6W                               FLYBOSNIA
# 3            AZ                  Alitalia Societa Aerea
# 4            HU                 Hainan Airlines Holding
# 5            5W              Wizz Air Abu Dhabi LLC dba
# 6            UD                         UR AIRLINES dba
# 7            IB                                  Iberia
# 8            N4                       Nordwind Airlines
# 9           QBA                    Queen Bilqis Airways
# 10           CY                        Charlie Airlines
# 11           7B  Limited Liability Company Bees Airline
# 12          VRH                              Varesh Air
# 13           GE              Global Aviation Operations
# 14           QH                          Bamboo Airways
# 15          KLJ                    Verslo skrydziai JSC

# %%
data.columns = ['A','B','C','D','E']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16892/1186650811.py in <module>
# ----> 1 data.columns = ['A','B','C','D','E']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ...

# %%
data.index = [4,5,6,7,8,8,9]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16892/2386476559.py in <module>
# ----> 1 data.index = [4,5,6,7,8,8,9]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ...

# %%
data
# Out:
#    Airline_code                            Airline_name
# 0            NS                          Nesma Airlines
# 1            UF                           PETROLEUM AIR
# 2            6W                               FLYBOSNIA
# 3            AZ                  Alitalia Societa Aerea
# 4            HU                 Hainan Airlines Holding
# 5            5W              Wizz Air Abu Dhabi LLC dba
# 6            UD                         UR AIRLINES dba
# 7            IB                                  Iberia
# 8            N4                       Nordwind Airlines
# 9           QBA                    Queen Bilqis Airways
# 10           CY                        Charlie Airlines
# 11           7B  Limited Liability Company Bees Airline
# 12          VRH                              Varesh Air
# 13           GE              Global Aviation Operations
# 14           QH                          Bamboo Airways
# 15          KLJ                    Verslo skrydziai JSC

# %%
(23+12+13)/4
# Out:
# 12.0

# %%
data.describe()
# Out:
#        Airline_code    Airline_name
# count            16              16
# unique           16              16
# top              NS  Nesma Airlines
# freq              1               1

# %%
data.head(10)
# Out:
#   Airline_code                Airline_name
# 0           NS              Nesma Airlines
# 1           UF               PETROLEUM AIR
# 2           6W                   FLYBOSNIA
# 3           AZ      Alitalia Societa Aerea
# 4           HU     Hainan Airlines Holding
# 5           5W  Wizz Air Abu Dhabi LLC dba
# 6           UD             UR AIRLINES dba
# 7           IB                      Iberia
# 8           N4           Nordwind Airlines
# 9          QBA        Queen Bilqis Airways

# %%
data.tail(3)
# Out:
#    Airline_code                Airline_name
# 13           GE  Global Aviation Operations
# 14           QH              Bamboo Airways
# 15          KLJ        Verslo skrydziai JSC

# %%
data[['Airline_code','Airline_name']]
# Out:
#    Airline_code                            Airline_name
# 0            NS                          Nesma Airlines
# 1            UF                           PETROLEUM AIR
# 2            6W                               FLYBOSNIA
# 3            AZ                  Alitalia Societa Aerea
# 4            HU                 Hainan Airlines Holding
# 5            5W              Wizz Air Abu Dhabi LLC dba
# 6            UD                         UR AIRLINES dba
# 7            IB                                  Iberia
# 8            N4                       Nordwind Airlines
# 9           QBA                    Queen Bilqis Airways
# 10           CY                        Charlie Airlines
# 11           7B  Limited Liability Company Bees Airline
# 12          VRH                              Varesh Air
# 13           GE              Global Aviation Operations
# 14           QH                          Bamboo Airways
# 15          KLJ                    Verslo skrydziai JSC

# %%
data['Airline_code'][1]
# Out:
# 'UF'

# %%
data['Airline_name'][7] = "Adity"

# %%
data
# Out:
#    Airline_code                            Airline_name
# 0            NS                          Nesma Airlines
# 1            UF                           PETROLEUM AIR
# 2            6W                               FLYBOSNIA
# 3            AZ                  Alitalia Societa Aerea
# 4            HU                 Hainan Airlines Holding
# 5            5W              Wizz Air Abu Dhabi LLC dba
# 6            UD                         UR AIRLINES dba
# 7            IB                                   Adity
# 8            N4                       Nordwind Airlines
# 9           QBA                    Queen Bilqis Airways
# 10           CY                        Charlie Airlines
# 11           7B  Limited Liability Company Bees Airline
# 12          VRH                              Varesh Air
# 13           GE              Global Aviation Operations
# 14           QH                          Bamboo Airways
# 15          KLJ                    Verslo skrydziai JSC

# %%
data['Airline_code'][3:10+1]
# Out:
# 3      AZ
# 4      HU
# 5      5W
# 6      UD
# 7      IB
# 8      N4
# 9     QBA
# 10     CY
# Name: Airline_code, dtype: object

# %%
data.loc[3:10,'Airline_code']='sdjd'

# %%
data
# Out:
#    Airline_code                            Airline_name
# 0            NS                          Nesma Airlines
# 1            UF                           PETROLEUM AIR
# 2            6W                               FLYBOSNIA
# 3          sdjd                  Alitalia Societa Aerea
# 4          sdjd                 Hainan Airlines Holding
# 5          sdjd              Wizz Air Abu Dhabi LLC dba
# 6          sdjd                         UR AIRLINES dba
# 7          sdjd                                   Adity
# 8          sdjd                       Nordwind Airlines
# 9          sdjd                    Queen Bilqis Airways
# 10         sdjd                        Charlie Airlines
# 11           7B  Limited Liability Company Bees Airline
# 12          VRH                              Varesh Air
# 13           GE              Global Aviation Operations
# 14           QH                          Bamboo Airways
# 15          KLJ                    Verslo skrydziai JSC

# %%
data.iloc[3:10,1]
# Out:
# 3        Alitalia Societa Aerea
# 4       Hainan Airlines Holding
# 5    Wizz Air Abu Dhabi LLC dba
# 6               UR AIRLINES dba
# 7                         Adity
# 8             Nordwind Airlines
# 9          Queen Bilqis Airways
# Name: Airline_name, dtype: object

# %%
data.sort_index(axis = 1 ,ascending = False)
# Out:
#                               Airline_name Airline_code
# 0                           Nesma Airlines           NS
# 1                            PETROLEUM AIR           UF
# 2                                FLYBOSNIA           6W
# 3                   Alitalia Societa Aerea         sdjd
# 4                  Hainan Airlines Holding         sdjd
# 5               Wizz Air Abu Dhabi LLC dba         sdjd
# 6                          UR AIRLINES dba         sdjd
# 7                                    Adity         sdjd
# 8                        Nordwind Airlines         sdjd
# 9                     Queen Bilqis Airways         sdjd
# 10                        Charlie Airlines         sdjd
# 11  Limited Liability Company Bees Airline           7B
# 12                              Varesh Air          VRH
# 13              Global Aviation Operations           GE
# 14                          Bamboo Airways           QH
# 15                    Verslo skrydziai JSC          KLJ

# %%
data.drop('Airline_name',axis = 1,inplace = True)

# %%
data
# Out:
#    Airline_code
# 0            NS
# 1            UF
# 2            6W
# 3          sdjd
# 4          sdjd
# 5          sdjd
# 6          sdjd
# 7          sdjd
# 8          sdjd
# 9          sdjd
# 10         sdjd
# 11           7B
# 12          VRH
# 13           GE
# 14           QH
# 15          KLJ

# %%
data[data['AIRLINE_NAME']=='Nesma Airlines']
# Out:
#   AIRLINE_code    AIRLINE_NAME
# 0           NS  Nesma Airlines

# %%
dataset = pd.read_csv('Salaries.csv')

# %%
Max_data = dataset['TotalPayBenefits'].max()

# %%
dataset[dataset['TotalPayBenefits']==Max_data]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
dataset['Year'].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
# dataset[dataset['Year'].apply(lambda x:x==2011)]

dataset[dataset['Year'].isin([2011,2013])]
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 110526  110527     Arthur L Curry
# 110527  110528      Nereida  Vega
# 110528  110529   Timothy E Gibson
# 110529  110530     Mark E Laherty
# 110530  110531      David P Kucia
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 110526                         PS Aide Health Services        NaN
# ...
